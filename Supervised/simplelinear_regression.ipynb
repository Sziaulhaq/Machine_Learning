# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("canada.csv")
df.head(4)
# Out:
#    year      income
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248

# %%
print(df.columns)
# Out:
# Index(['year', 'income '], dtype='object')

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('income')
plt.scatter(df['year'], df['income '], color='red', marker='*')

# %%
reg= linear_model.LinearRegression()
reg.fit(df[['year']],df['income '] )
# Out:
# LinearRegression()

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('income')
plt.scatter(df['year'], df['income '], color='red', marker='*')
plt.plot(df.year,reg.predict(df[['year']]),color='blue')

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# np.float64(-1632210.7578554575)

# %%
reg.predict([[2020]])
# Out:
# C:\Users\HARSHITA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
